# %% [markdown]
# # Text index

# %%
import asyncio
import json
import math
import os
import pickle
import re
import unicodedata

import faiss
import nest_asyncio
import numpy as np
import pandas as pd
import torch
from PIL import Image
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer
from stopwordsiso import stopwords
from telethon import TelegramClient
from transformers import (
    CLIPProcessor,
    CLIPModel,
    BlipForConditionalGeneration,
    BlipProcessor,
)

# %%
# Показывать все столбцы
pd.set_option('display.max_columns', None)
# Не обрезать ширину таблицы по общему числу символов
pd.set_option('display.width', None)
# Показывать весь текст в ячейках (не обрезать по ширине)
pd.set_option('display.max_colwidth', None)


# 1. Загрузка
with open("news_data2.json", encoding="utf-8") as f:
    raw = json.load(f)
df = pd.DataFrame(raw)
df.head(1)
# Out:
#        category   channel  message_id        time  \
# 0  General news  @rian_ru      291023  25.04.2025
#
#                                                                                                                     text  \
# 0  Разведка Индии на фоне обострения отношений с Пакистаном предупредила о возможности новых терактов в Джамму и Кашмире
#
#   image_path
# 0

# %%
old_text = ""
new_text = " "

# Заменяем None/NaN на пустую строку
df["text"] = df["text"].fillna("")

# Применяем replace только к тем строкам, у которых длина < 2
df["text"] = [
    path.replace(old_text, new_text) if len(path) < 2 else path
    for path in df["text"]
]

# 3. Предобработка
ru_stop = stopwords("ru")
def clean(text: str) -> str:
    text = BeautifulSoup(text, "html.parser").get_text(" ", strip=True)
    text = unicodedata.normalize("NFKC", text).lower()
    text = re.sub(r"[^\w\s]", " ", text)
    tokens = [t for t in text.split() if t not in ru_stop]
    return " ".join(tokens)
df["clean_text"] = df["text"].map(clean)

# 4. Фильтрация коротких новостей
df["word_count"] = df["clean_text"].str.split().apply(len)
df = df[df["word_count"] > 7].reset_index(drop=True)
df = df.drop(columns=["word_count"])

months = {
    '01': 'января', '02': 'февраля', '03': 'марта', '04': 'апреля',
    '05': 'мая', '06': 'июня', '07': 'июля', '08': 'августа',
    '09': 'сентября', '10': 'октября', '11': 'ноября', '12': 'декабря'
}
df['time_'] = df['time'].str.replace(
    r'(\d{2})\.(\d{2})\.\d{4}',
    lambda m: f"{int(m.group(1))} {months[m.group(2)]}",
    regex=True
)

df["clean_text"] = df["time_"] + " " + df["clean_text"]

df.head(1)
# Out:
#        category   channel  message_id        time  \
# 0  General news  @rian_ru      291023  25.04.2025
#
#                                                                                                                     text  \
# 0  Разведка Индии на фоне обострения отношений с Пакистаном предупредила о возможности новых терактов в Джамму и Кашмире
#
#   image_path  \
# 0
#
#                                                                                                              clean_text  \
# 0  25 апреля разведка индии фоне обострения отношений пакистаном предупредила возможности новых терактов джамму кашмире
#
#        time_
# 0  25 апреля

# %%
news_image_text = df[
    df["image_path"].notna()            # не NaN/None
    & df["image_path"].ne("")           # не пустая строка
]
news_image_text.head(1)
# Out:
#         category   channel  message_id        time  \
# 10  General news  @rian_ru      291006  25.04.2025
#
#                                                                                                                                                                                                                                                                                                                                              text  \
# 10  На фоне обострения между Индией и Пакистаном РИА Новости сравнило военные потенциалы двух стран.\n\nОборонный бюджет Индии почти в 10 раз превышает расходы Пакистана на армию. В авиации, живой силе и танках у Индии преимущество примерно в два раза.\n\nПри этом по числу ядерных боезарядов у Исламабада и Нью-Дели практически паритет.
#
#                                                   image_path  \
# 10  /content/drive/MyDrive/Diploma/images/rian_ru_291006.jpg
#
#                                                                                                                                                                                                                                                                            clean_text  \
# 10  25 апреля фоне обострения индией пакистаном риа новости сравнило военные потенциалы стран оборонный бюджет индии 10 превышает расходы пакистана армию авиации живой силе танках индии преимущество примерно раза числу ядерных боезарядов исламабада нью дели практически паритет
#
#         time_
# 10  25 апреля

# %%
news_image_paths = df[
    df["image_path"].notna()            # не NaN/None
    & df["image_path"].ne("")           # не пустая строка
]
news_image_paths = list(news_image_paths["image_path"])

# %%
len(news_image_paths[0])
# Out:
# 56

# %%
# Преобразуем Series в обычный список
texts = df["clean_text"].tolist()

# Сформируем нужную структуру
data = {
    "clean_text": texts
}

# Сохраним в файл в человекочитаемом виде с Unicode напрямую
with open("gpt_news.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
from sentence_transformers import SentenceTransformer

text = df['clean_text']
encoder = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2") # bert-base-nli-mean-tokens

# %%
embeddings = encoder.encode(text)

# %%
embeddings
# Out:
# array([[-0.09420574, -0.00633919, -0.13923542, ...,  0.17324284,
#         -0.04576061, -0.01844954],
#        [-0.0217472 ,  0.25407398, -0.15008026, ...,  0.21548347,
#         -0.3479332 ,  0.09033651],
#        [-0.14909697,  0.00256209, -0.04424019, ..., -0.04633314,
#         -0.14459951, -0.09079548],
#        ...,
#        [-0.31644922,  0.24303204,  0.04689507, ..., -0.06389456,
#          0.11051159,  0.22291371],
#        [-0.21578182,  0.10785401,  0.01316834, ..., -0.01632707,
#          0.01277807, -0.02064398],
#        [-0.20739281,  0.078646  ,  0.16746822, ..., -0.035949  ,
#          0.11581522,  0.04504444]], shape=(5199, 384), dtype=float32)

# %%
embeddings.shape
# Out:
# (5199, 384)

# %%
import faiss
vector_dimensions = embeddings.shape[1]

index = faiss.IndexFlatL2(vector_dimensions)
faiss.normalize_L2(embeddings)
index.add(embeddings)

# %%
faiss.write_index(index, "news_date.faiss")

# %%
import numpy as np

search_text = '16 апреля Новости про Украину '
search_vector = encoder.encode(search_text)
new_vector = np.array([search_vector])
faiss.normalize_L2(new_vector)
distances, ann = index.search(new_vector, k=5)
indices = ann[0]
top_texts = df['clean_text'].iloc[indices].reset_index(drop=True)
results = pd.DataFrame({
    'distances': distances[0],
    'clean_text': top_texts
})

results
# Out:
#    distances  \
# 0   0.439951
# 1   0.461347
# 2   0.489277
# 3   0.499606
# 4   0.502487
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                clean_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            13 сентября одна причин украина пользуется поддержкой странах rt госдеп зря прожила серьезно
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          23 апреля заявления пескова урегулирования украине нюансов сближать позиции продолжается сша продолжают посреднические усилия урегулированию украине приветствует расценивает слова вэнса возможном выходе сша переговорного процесса украине ультиматум стороны вашингтона любые наброски вариантов украинского урегулирования публичными иначе потеряют эффективность прежнему выступает европейских миротворцев украине определилась представлять похоронах папы римского генсек оон планирует приезжать москву 80 летие победы путин среду проведет заседание военно промышленной комиссии
# 2  22 июля вашингтон брюссель осуществляют геноцид украинского народа согласно идеологии сотни жителей украины должны погибнуть фронте киевскому режиму поставляется большее количество вооружения остальные потерять национальную идентичность решения задачи используются имперские амбиции польши зеленский принял решений ставших огромной трагедией украинского народа закон фактически приравняет поляков украинцам предоставив права нахождение территории страны разрешений трудоустройство обучение медобслуживание некоторые выплаты приграничных россией областях сумской черниговской родных домов выгоняют украинцев стремясь заменить лояльных нацистам переселенцев поляков гражданам украины вместо русского навязывается польский язык включён список экзаменов вузы организуются гонения православную веру украинцев обращают католичество одним словом зеленский ведёт процесс ополячивания страны надеясь благодарность хозяева дадут возможность подольше удержаться власти фоне создано 25 тысячное воинское соединение состоящее основном польских литовских вооружённых солдат готовых оккупации западной украины поляки хотят вернуть считают исторические земли восточные кресы граждане украины территориях нужны вашингтон брюссель продолжат вести войну последнего украинца
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           20 октября территорий является первостепенным украины урегулировании конфликта россией the telegraph восприняла слова украинского посла великобритании бывшего главкома всу валерия залужного сильно меняется риторика интересно подписаться прислать новость
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          16 мая киевский режим втягивает сша страны европы большую войну депутаты рады украины пытаются убедить вашингтон разрешить применение поставляемых сша вооружений поражения целей территории россии ведёт трагедии затронуть человечество киевский режим проигрывая поле боя пытается втянуть соединённые штаты страны европы большую войну любое использование американского европейского оружия нанесения ударов мирным городам российской федерации потребует применения мощного оружия защитить граждан нашей страны западным политикам необходимо осознать ответственность доводить ситуацию катастрофы мирового масштаба

# %%
results
# Out:
#    distances  \
# 0   0.440108
# 1   0.489277
# 2   0.494198
# 3   0.499606
# 4   0.502487
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                clean_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   16 апреля украина привлекала боевым действиям угледаре днр наемников арабских стран сообщил риа новости житель города
# 1  22 июля вашингтон брюссель осуществляют геноцид украинского народа согласно идеологии сотни жителей украины должны погибнуть фронте киевскому режиму поставляется большее количество вооружения остальные потерять национальную идентичность решения задачи используются имперские амбиции польши зеленский принял решений ставших огромной трагедией украинского народа закон фактически приравняет поляков украинцам предоставив права нахождение территории страны разрешений трудоустройство обучение медобслуживание некоторые выплаты приграничных россией областях сумской черниговской родных домов выгоняют украинцев стремясь заменить лояльных нацистам переселенцев поляков гражданам украины вместо русского навязывается польский язык включён список экзаменов вузы организуются гонения православную веру украинцев обращают католичество одним словом зеленский ведёт процесс ополячивания страны надеясь благодарность хозяева дадут возможность подольше удержаться власти фоне создано 25 тысячное воинское соединение состоящее основном польских литовских вооружённых солдат готовых оккупации западной украины поляки хотят вернуть считают исторические земли восточные кресы граждане украины территориях нужны вашингтон брюссель продолжат вести войну последнего украинца
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             15 апреля заявления пескова украинскому урегулированию идет достаточно напряженная положительные результаты сиюминутных стоит четких очертаний соглашения украинскому урегулированию политическая воля двигаться сторону экономическое сотрудничество россии сша сыграть стабилизирующую роль очевидно рада москве готов разделить гордость радость дня победы ожидает парад победы 20 глав правительств архиважный разговора трампом течение ближайших нескольких дней графике путина слова главы евродипломатии каллас высказалась присутствии представителей ес москве расценивать весьма весьма жесткие
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           20 октября территорий является первостепенным украины урегулировании конфликта россией the telegraph восприняла слова украинского посла великобритании бывшего главкома всу валерия залужного сильно меняется риторика интересно подписаться прислать новость
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          16 мая киевский режим втягивает сша страны европы большую войну депутаты рады украины пытаются убедить вашингтон разрешить применение поставляемых сша вооружений поражения целей территории россии ведёт трагедии затронуть человечество киевский режим проигрывая поле боя пытается втянуть соединённые штаты страны европы большую войну любое использование американского европейского оружия нанесения ударов мирным городам российской федерации потребует применения мощного оружия защитить граждан нашей страны западным политикам необходимо осознать ответственность доводить ситуацию катастрофы мирового масштаба

# %%
def retrieve_similar_documents(search_text: str, k: int = 5):
    """Возвращает список из k наиболее релевантных текстовых фрагментов для заданного запроса."""
    search_vector = encoder.encode(search_text)
    new_vector = np.array([search_vector])
    faiss.normalize_L2(new_vector)
    distances, ann = index.search(new_vector, k=5)
    indices = ann[0]
    top_texts = df['clean_text'].iloc[indices].reset_index(drop=True)
    results = pd.DataFrame({
        'distances': distances[0],
        'clean_text': top_texts
    })
    return results

# Пример использования:
user_query = "Сколько Академику Алексею Матвеевичу Липанову?"
results = retrieve_similar_documents(user_query, k=10)
results
# Out:
#    distances  \
# 0   0.755482
# 1   0.797171
# 2   0.814344
# 3   0.839260
# 4   0.880265
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  clean_text
# 0  20 марта 20 марта 1980 президиум ан ссср принял постановление no 314 организации куйбышеве филиала физического института имени п н лебедева ан ссср самарский куйбышевский филиал фиан организован 1980 совместной инициативе областного руководства лауреата нобелевской премии академика николая геннадиевича басова решения фундаментальных прикладных задач области создания новых лазерных систем технологий первым директором филиала дважды лауреат государственной премии доктор физ мат наук профессор виктор анатольевич катулин руководством молодой коллектив провёл огромную работу короткий срок филиал обеспечен установками производственными площадями получены новые научные результаты лазерной технологии технологическим лазерам решены актуальные фундаментальные инженерные задачи установлено плодотворное сотрудничество вузами предприятиями нии нашей стране рубежом учёный вспоминал филиал начинается высадки волжские берега московского научного десанта группы молодых физиков воспитанников фиана кандидатов наук творческих дерзких исследователей ядро костяк коллектива предоставлено двухэтажное здание места теоретиков группы мощными лазерами предоставляет университет ближайшее предполагается строительство комплекса зданий института берегу волги лазерный комплекс расположится неподалёку университета интервью виктора анатольевича катулина волжская заря номер 24 07 1980 сф фиан живёт прочитать выше
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             26 марта нападающий авангарда илья каблуков первым хоккеистом истории кхл принявшим участие 16 кубках гагарина 15 участий василия кошечкина евгения бирюкова кирилла петрова егора аверина ранее 37 летний форвард третьим хоккеистом проведшим 1000 матчей лиге лидером играм является вадим шипачёв 1036 1000 преодолел евгений бирюков 1001 завершивший карьеру pro хоккей
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        15 апреля овечкин заработал истории хоккея статистический портал sportrac приводит следующие цифры ови получил карьеру нхл 161 72 благодаря контракта вашингтоном доходы россиянина вырастут 170 72 тройку заработку вошли сидни кросби 155 89 млн евгений малкин 146 87 млн подписаться sportrian
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         11 апреля 1 2 3 хоккейный агент шуми бабаев представляющий интересы нападающего ска сергея толчинского отреагировал слухи возможном уходе форварда армейского клуба информация соответствуют действительности сергея действующий контракт роман борисович чётко дал рассчитывает игрока следующем сезоне лидера толчинского сильного выступления ухода ска обсуждался обсуждается напомним контракт толчинского рассчитан 31 мая 2028 ранее форвард подписал пятилетний контракт прошло сезоне 2024 2025 толчинский провёл 51 матч набрал 16 7 9 очков pro хоккей
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                17 апреля поздравляем владимира михайловича алпатова 80 летием труды стали неотъемлемой частью лингвистического ландшафта россии научное наследие академика вдохновляет исследователей способствует развитию науки желаем здоровья благополучия юбилеи_ран

# %% [markdown]
# # CLIP index

# %%
import torch
from transformers import CLIPProcessor, CLIPModel,  CLIPTokenizer
from transformers import BlipProcessor, BlipForConditionalGeneration


# Загрузка CLIP модели для работы с изображениями
print("Загрузка CLIP-модели...")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")
clip_model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
clip_tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")

clip_index = faiss.read_index("clip_index_last.faiss" )

print("CLIP-модель загружена.")
# Out:
# Загрузка CLIP-модели...
# CLIP-модель загружена.

# %%
with open("clip_valid_paths.pkl", "rb") as f:
    clip_valid_paths = pickle.load(f)
clip_valid_paths
# Out:
# ['/content/drive/MyDrive/Diploma/images/rian_ru_290404.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290403.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290398.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290387.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290379.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290371.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290359.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290358.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290357.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290356.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290353.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290347.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290346.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290344.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290338.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290335.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290333.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290332.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290325.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290320.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290319.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290318.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290317.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290316.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290315.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290314.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290313.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290312.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290303.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290295.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290290.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290286.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290284.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290280.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290276.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290275.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290274.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290264.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290261.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290251.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290245.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290237.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290236.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290233.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290232.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290226.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290225.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290224.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290223.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290221.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290219.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290213.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290212.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290211.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290210.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290206.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290205.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290200.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290194.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290180.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290179.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290178.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290177.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290174.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290173.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290165.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290164.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290163.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290162.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290161.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290160.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290159.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290158.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290157.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290150.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290132.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290130.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290125.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290118.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290116.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290105.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290101.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290100.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290096.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290092.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290090.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290084.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290082.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290081.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290080.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290062.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290056.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290053.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290050.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290042.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290041.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290037.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290036.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290023.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290019.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290016.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290006.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290004.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_290001.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289994.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289993.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289992.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289991.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289990.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289986.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289985.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289984.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289983.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289980.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289977.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289970.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289957.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289954.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289937.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289934.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289933.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289932.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289922.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289919.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289918.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289917.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289916.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289915.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289908.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289907.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289906.jpg',
#  '/content/drive/MyDrive/Diploma/images/rian_ru_289905.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52621.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52620.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52619.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52618.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52617.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52615.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52614.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52613.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52612.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52611.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52610.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52609.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52607.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52606.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52605.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52598.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52596.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52595.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52594.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52593.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52592.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52591.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52590.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52589.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52588.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52587.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52586.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52585.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52584.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52583.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52582.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52581.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52580.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52579.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52578.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52576.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52574.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52572.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52571.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52569.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52568.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52567.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52566.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52565.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52564.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52563.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52562.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52561.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52560.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52558.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52557.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52556.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52554.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52551.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52549.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52544.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52542.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52541.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52540.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52539.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52538.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52537.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52536.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52533.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52531.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52530.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52529.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52526.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52525.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52523.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52522.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52521.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52520.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52519.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52518.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52516.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52515.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52514.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52513.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52512.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52511.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52509.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52507.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52505.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52504.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52503.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52502.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52501.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52500.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52499.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52498.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52496.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52495.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52494.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52493.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52492.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52491.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52490.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52489.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52488.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52487.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52486.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52485.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52484.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52483.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52481.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52480.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52479.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52477.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52476.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52475.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52474.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52473.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52472.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52471.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52470.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52469.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52468.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52467.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52466.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52465.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52462.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52461.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52460.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52459.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52458.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52457.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52455.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52454.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52453.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52451.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52450.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52448.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52445.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52444.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52443.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52442.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52441.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52440.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52437.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52436.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52434.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52433.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52432.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52431.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52430.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52429.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52427.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52426.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52424.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52423.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52422.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52421.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52420.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52419.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52418.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52417.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52416.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52415.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52414.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52413.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52412.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52411.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52410.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52409.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52408.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52407.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52406.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52405.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52404.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52403.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52401.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52398.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52397.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52396.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52390.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52389.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52388.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52387.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52386.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52385.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52384.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52383.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52382.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52379.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52378.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52377.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52376.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52373.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52368.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52367.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52366.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52361.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52360.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52359.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52357.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52356.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52355.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52354.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52353.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52352.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52351.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52350.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52346.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52345.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52344.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52343.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52342.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52341.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52340.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52339.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52337.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52336.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52335.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52334.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52333.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52332.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52331.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52330.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52329.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52325.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52320.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52318.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52314.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52313.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52312.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52311.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52310.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52308.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52307.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52304.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52303.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52302.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52299.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52298.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52297.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52294.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52293.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52292.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52291.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52290.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52289.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52288.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52287.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52285.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52284.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52281.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52280.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52279.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52277.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52276.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52275.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52267.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52266.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52262.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52260.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52259.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52257.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52255.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52254.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52253.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52252.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52251.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52249.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52248.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52246.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52245.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52244.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52243.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52242.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52241.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52239.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52232.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52231.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52230.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52229.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52228.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52227.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52226.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52225.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52224.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52223.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52222.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52221.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52220.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52219.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52218.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52217.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52216.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52215.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52214.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52213.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52212.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52211.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52210.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52209.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52208.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52205.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52204.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52203.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52202.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52201.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52200.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52199.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52198.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52197.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52196.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52195.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52194.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52192.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52191.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52190.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52188.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52187.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52185.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52184.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52183.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52182.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52181.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52180.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52179.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52178.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52177.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52176.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52171.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52170.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52169.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52168.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52167.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52166.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52165.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52164.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52163.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52162.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52160.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52159.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52158.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52157.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52156.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52155.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52154.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52153.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52152.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52150.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52149.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52147.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52145.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52143.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52142.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52141.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52136.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52135.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52134.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52132.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52130.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52128.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52127.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52126.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52125.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52124.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52122.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52121.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52120.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52118.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52117.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportrian_52116.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111632.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111630.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111628.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111626.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111625.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111624.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111622.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111621.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111620.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111619.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111618.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111617.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111616.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111615.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111614.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111613.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111612.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111611.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111610.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111609.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111608.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111607.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111606.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111605.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111604.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111603.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111602.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111600.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111599.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111598.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111596.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111595.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111592.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111589.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111588.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111587.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111586.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111585.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111584.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111583.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111582.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111581.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111580.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111579.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111578.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111577.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111576.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111575.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111574.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111572.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111571.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111569.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111568.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111567.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111566.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111565.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111564.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111562.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111561.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111560.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111559.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111557.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111556.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111555.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111553.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111552.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111550.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111549.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111548.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111546.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111544.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111543.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111542.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111541.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111540.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111539.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111538.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111537.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111535.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111534.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111533.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111532.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111529.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111528.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111526.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111525.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111521.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111520.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111519.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111518.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111517.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111515.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111514.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111513.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111512.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111511.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111510.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111509.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111508.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111506.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111505.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111504.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111503.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111502.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111501.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111500.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111499.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111498.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111494.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111493.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111492.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111491.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111488.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111487.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111486.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111485.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111484.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111483.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111482.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111481.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111480.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111479.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111478.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111477.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111476.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111474.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111473.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111472.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111471.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111470.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111469.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111468.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111467.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111465.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111464.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111463.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111462.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111461.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111460.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111459.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111458.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111456.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111455.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111454.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111452.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111451.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111447.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111446.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111445.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111444.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111443.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111442.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111441.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111439.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111438.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111437.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111436.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111435.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111434.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111433.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111432.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111431.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111430.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111429.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111428.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111427.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111426.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111424.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111423.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111422.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111420.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111419.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111418.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111417.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111416.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111412.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111411.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111410.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111409.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111408.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111407.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111406.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111404.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111403.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111402.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111400.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111399.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111397.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111395.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111394.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111393.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111392.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111391.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111390.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111388.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111386.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111384.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111382.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111381.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111379.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111378.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111377.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111376.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111375.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111372.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111370.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111368.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111367.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111366.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111365.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111364.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111363.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111362.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111361.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111360.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111359.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111358.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111356.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111354.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111353.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111352.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111348.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111347.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111346.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111345.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111344.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111343.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111342.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111340.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111339.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111336.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111335.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111334.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111333.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111332.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111331.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111330.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111329.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111328.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111327.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111326.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111325.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111324.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111322.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111321.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111320.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111319.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111318.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111317.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111316.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111315.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111314.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111313.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111312.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111311.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111310.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111309.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111308.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111307.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111305.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111304.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111303.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111302.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111298.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111297.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111292.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111291.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111290.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111289.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111288.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111287.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111285.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111284.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111283.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111282.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111280.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111278.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111277.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111276.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111275.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111274.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111272.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111270.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111268.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111267.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111266.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111265.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111262.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111261.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111260.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111259.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111258.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111257.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111256.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111255.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111254.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111252.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111249.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111247.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111246.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111244.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111243.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111242.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111241.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111239.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111238.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111237.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111236.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111231.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111230.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111229.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111228.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111227.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111226.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111225.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111224.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111223.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111222.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111221.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111220.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111219.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111217.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111216.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111214.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111211.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111210.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111208.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111207.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111206.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111205.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111202.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111201.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111200.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111197.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111195.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111194.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111193.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111192.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111191.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111190.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111189.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111188.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111187.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111185.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111184.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111183.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111182.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111181.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111180.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111179.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111178.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111177.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111175.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111174.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111173.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111172.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111171.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111170.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111168.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111167.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111166.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111165.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111164.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111162.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111161.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111159.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111158.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111157.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111156.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111155.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111154.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111152.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111151.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111150.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111149.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111148.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111146.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111145.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111144.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111142.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111134.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111133.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111130.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111129.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111125.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111124.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111120.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111118.jpg',
#  '/content/drive/MyDrive/Diploma/images/sportsru_111116.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8061.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8060.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8059.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8058.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8056.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8054.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8053.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8052.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8050.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8047.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8044.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8043.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8042.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8041.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8039.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8038.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8037.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8016.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8014.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8013.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8012.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8009.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8008.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8007.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8001.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_8000.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7999.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7981.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7980.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7979.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7976.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7975.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7972.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7965.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7963.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7962.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7961.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7960.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7959.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7958.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7957.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7955.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7948.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7945.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7944.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7927.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7926.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7925.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7924.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7922.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7891.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7890.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7888.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7884.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7881.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7877.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7873.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7872.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7868.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7866.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7865.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7863.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7858.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7857.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7856.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7854.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7853.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7846.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7845.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7842.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7840.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7839.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7838.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7837.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7824.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7823.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7822.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7821.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7819.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7818.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7815.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7814.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7813.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7812.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7811.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7810.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7809.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7808.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7807.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7805.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7804.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7803.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7802.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7799.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7798.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7797.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7794.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7793.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7792.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7791.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7790.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7789.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7788.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7787.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7786.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7785.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7782.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7781.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7780.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7779.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7778.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7774.jpg',
#  '/content/drive/MyDrive/Diploma/images/football_nik_7772.jpg',
#  ...]

# %%
# Старый путь, который нужно заменить
old_prefix = "/content/drive/MyDrive/Diploma/images/"
# Новый путь
new_prefix = "/Applications/Study/Diploma/images/"

# Обновляем все пути
clip_valid_paths = [path.replace(old_prefix, new_prefix) for path in clip_valid_paths]

# %%
with open("clip_valid_paths.pkl", "wb") as f:
    pickle.dump(clip_valid_paths, f)

# %%
with open('news_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Предполагается, что JSON содержит ключи "text", "image_path" и "category"
news_texts = data["text"]
df = pd.DataFrame(data) 
news_image_paths = df[
    df["image_path"].notna()            # не NaN/None
    & df["image_path"].ne("")           # не пустая строка
]
news_image_paths = list(news_image_paths["image_path"])[0:5]

# %%
news_image_paths
# Out:
# ['/Applications/Study/Diploma/images/rian_ru_289957.jpg',
#  '/Applications/Study/Diploma/images/rian_ru_289954.jpg',
#  '/Applications/Study/Diploma/images/rian_ru_289937.jpg',
#  '/Applications/Study/Diploma/images/rian_ru_289934.jpg',
#  '/Applications/Study/Diploma/images/rian_ru_289933.jpg']

# %%
# ------------------------
# 3. Построение CLIP индекса (clip_index)
# ------------------------
clip_embeddings = []
clip_valid_paths = []  # Список успешно загруженных изображений

print("Вычисление эмбеддингов для изображений (CLIP)...")
for img_path in news_image_paths:
    try:
        image = Image.open(img_path).convert("RGB")
    except Exception as e:
        print(f"Ошибка при загрузке изображения {img_path}: {e}")
        continue
    inputs = clip_processor(images=image, return_tensors="pt")
    with torch.no_grad():
        embedding = clip_model.get_image_features(**inputs)
    embedding = embedding.cpu().numpy().astype("float32")
    clip_embeddings.append(embedding[0])
    clip_valid_paths.append(img_path)

if clip_embeddings:
    clip_embeddings = np.vstack(clip_embeddings)
    d_clip = clip_embeddings.shape[1]
    clip_index = faiss.IndexFlatL2(d_clip)
    clip_index.add(clip_embeddings)
    faiss.write_index(clip_index, "clip_index_last.faiss")
    print(f"Число изображений в CLIP индексе: {clip_index.ntotal}")
else:
    print("Нет доступных изображений для формирования CLIP индекса.")
# Out:
# Вычисление эмбеддингов для изображений (CLIP)...
# Число изображений в CLIP индексе: 5

# %%
import faiss, numpy as np
TEXT_INDEX_PATH = "news_date.faiss"    # FAISS index for text embeddings
CLIP_INDEX_PATH = "clip_index_last.faiss"         # FAISS index for image (CLIP) embeddings
BLIP_INDEX_PATH = "blip_index_last.faiss"         # FAISS index for BLIP caption embeddings
CLIP_PATHS_PATH = "clip_valid_paths.pkl"     # to store list of image paths corresponding to CLIP embeddings
BLIP_CAPTIONS_PATH = "blip_captions.pkl" 

# 3. Построение CLIP индекса (clip_index)
  # non-empty path
clip_embeddings_list = []
valid_paths = []
for img_path in news_image_paths:
    try:
        # Load image and compute CLIP image embedding
        image = Image.open(img_path).convert("RGB")
        inputs = clip_processor(images=image, return_tensors="pt")
        with torch.no_grad():
            img_emb = clip_model.get_image_features(**inputs)
        # Move embedding to CPU and convert to numpy array
        emb_np = img_emb.cpu().numpy().astype("float32")
        clip_embeddings_list.append(emb_np[0])
        valid_paths.append(img_path)
    except Exception as e:
        print(f"Error processing image {img_path}: {e}")
        continue
if clip_embeddings_list:
    clip_embeddings = np.vstack(clip_embeddings_list)
    clip_index = faiss.read_index(CLIP_INDEX_PATH)
    clip_index.add(clip_embeddings)
    faiss.write_index(clip_index, CLIP_INDEX_PATH)
    # Save the list of valid image paths corresponding to the index vectors
    with open(CLIP_PATHS_PATH, "wb") as f:
        import pickle
        pickle.dump(valid_paths, f)
    print(f"Image index updated. Total images indexed: {clip_index.ntotal}")
else:
    # If no images or all failed
    print("No images available to update CLIP index.")
# Out:
# Image index updated. Total images indexed: 4330

# %%
clip_embeddings = np.vstack(clip_embeddings)

clip_index   = faiss.read_index("clip_index_last.faiss")

print("index.d        :", clip_index.d)          # чему обучался индекс
print("new vec shape :", clip_embeddings.shape)  # (N, d_new)
print("dtype          :", clip_embeddings.dtype) # должен быть float32
# Out:
# index.d        : 768
# new vec shape : (5, 768)
# dtype          : float32

# %%
import pickle

# Сохраняем индекс Faiss
faiss.write_index(clip_index, "/content/drive/MyDrive/Diploma/clip_index_last.faiss")

# Сохраняем пути к изображениям, соответствующие эмбеддингам
with open("/content/drive/MyDrive/Diploma/clip_valid_paths.pkl", "wb") as f:
    pickle.dump(clip_valid_paths, f)

print("CLIP индекс и пути к изображениям успешно сохранены.")

# %%
i = faiss.read_index("clip_index_last.faiss")
i.ntotal
# Out:
# 4320

# %% [markdown]
# # BLIP index

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# Загрузка BLIP модели для генерации подписей к изображениям
print("Загрузка BLIP-модели...")
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")
print("BLIP-модель загружена.")
# Out:
# Загрузка BLIP-модели...
# BLIP-модель загружена.

# %%
with open("blip_captions.pkl", "rb") as f:
    blip_captions = pickle.load(f)
blip_captions
# Out:
# ['a map of the russian region of moscow with the most major cities',
#  'a map of ukraine showing the location of the major cities',
#  'a close up of a passport with a picture of a man',
#  "a blue background with a white text that reads, ' russian hoboc '",
#  'there is a man in a blue shirt and glasses sitting in a chair',
#  "arafed image of a man in a priest ' s robes on a time magazine cover",
#  'purple table with a purple cloth and a picture of a man with a candle',
#  'woman sitting at a table writing in a book with a picture of a man',
#  'a close up of a book with a picture of a pope on it',
#  'a close up of a tree with the sun shining through the leaves',
#  'flags of european union and european union flag flying in front of the european parliament',
#  'arafed image of two men standing next to each other in a room',
#  'purple flowers blooming on a tree in a city park',
#  'arafed image of a priest standing in front of a microphone',
#  'a close up of a document with a picture of a person on it',
#  'arafian rocket launching a satellite into the sky with a large cloud',
#  'people sitting on the grass by the water with bikes',
#  'a close up of a person shaking hands with a man in a suit',
#  'arafed man in a suit shaking hands with a man in a yellow tie',
#  'a close up of a document with a picture of a person on it',
#  'a close up of a man sitting in a chair with a pope on it',
#  'pope benedict waves to the crowd as he arrives for his weekly general audience',
#  'arafed pope shakes hands with a nun in front of a crowd of people',
#  'arafed image of a group of men sitting around a table',
#  'arafed pope waves to the crowd as he arrives for his weekly general audience',
#  'pope benedict greets a crowd of people at a mass',
#  'arafed man in a white robe sitting in a chair with a microphone',
#  'arafed image of a man sitting at a table with a laptop',
#  'there is a clock on a pole in front of a tree',
#  'a close up of a car being assembled in a factory',
#  'snow covered scooters are lined up on the sidewalk in front of a building',
#  'there is a road that has been dug in the middle of the road',
#  'smoke billows from a building on fire in a city',
#  'a close up of a calendar with numbers on it',
#  'a close up of a cell phone with a number of different languages',
#  'a close up of a cell phone with a number of different languages',
#  'a poster with a picture of a building and a lot of money',
#  'there are two men sitting at a table talking to each other',
#  "a blue background with a white text that reads, ' russian hoboc '",
#  'there is a woman sitting at a table with a plate of food',
#  'arafficial image of a priest with a group of people',
#  'woman laying on the grass while talking on her cell phone',
#  'map of the region of the russian border with the location of the city of pokva',
#  'there are two men standing on a boat in the water',
#  'there is a large boat that is in the water with a sign on it',
#  'a screenshot of a twee with a picture of two men walking down the street',
#  'a screenshot of a man standing in front of a tank',
#  'arafed image of a man in a suit and tie sitting in a church',
#  'a close up of a tv screen with a picture of a priest',
#  'arafed image of a man in a suit lighting a candle',
#  'people walking on a bridge with a city in the background',
#  "there are five stone sculptures of a woman ' s head on a bench",
#  'arafed stone column with writing on it with a marker in front of it',
#  'there is a small door in the middle of a stone wall',
#  'two statues of a woman and a man are shown in two different poses',
#  'people holding candles in front of a building with a crowd of people standing around',
#  'several people are standing outside of a church holding candles',
#  'arafed image of a priest standing at a pulpit in a church',
#  'arafed woman in a black jacket and white shirt looking at the camera',
#  'a screenshot of a website with a picture of a building and a clock',
#  'a close up of a text message on a computer screen',
#  'arafed image of a man in military uniform sitting at a desk',
#  'arafed image of a man in a suit and tie sitting at a desk',
#  'arafed man in glasses and a tie speaking into a microphone',
#  'a screenshot of a man standing in front of a truck in the woods',
#  'a close up of a cell phone with a newspaper on it',
#  'a screenshot of a newspaper page with a picture of a person on a cell phone',
#  'a screenshot of a newspaper with a picture of a man in a suit',
#  'a close up of two pictures of a man in a suit and tie',
#  'arafed article on the russian president on the internet',
#  'araffatt news on the app of a man in a suit',
#  'a screenshot of a man in a suit and tie giving a speech',
#  'a close up of a newspaper page with a picture of a man in a suit',
#  'a close up of a person in a suit and tie standing in front of a statue',
#  "a blue background with a white text that reads, ' russian hoboc '",
#  'woman walking in the rain with an umbrella in her hand',
#  'there are two old brass fire hydrants sitting on a stone wall',
#  'woman walking down the street in white clothes and heels',
#  'people walking along a river bank with a bike leaning against a wall',
#  'a blue car parked in a large warehouse with a yellow line',
#  'arafed man wearing a hat and sunglasses at a sporting event',
#  'arafed image of a group of men in black robes standing in front of a church',
#  'there is a train that is parked inside of a building',
#  'map of the region of ukraine with a red arrow pointing to the capital',
#  'cars driving on a snowy street in a city during a blizzard',
#  'three men in suits cutting a ribbon at a ceremony',
#  'a close up of a priest holding a cross in front of a crowd',
#  'a screenshot of a newspaper article with a man in a suit and tie walking past a car',
#  'a close up of a man in a suit and tie sitting at a table',
#  'a newspaper article about a fire that is burning in the air',
#  'several people lounging on lounge chairs on a beach with a cell phone',
#  'arafed view of a church with a clock tower and a yellow flower',
#  'there are two men standing next to each other holding a plaque',
#  'there is a dog that is wearing a vest on a leash',
#  'lightning strikes through the sky over a city at night',
#  'there is a man with a mustache and glasses wearing a suit',
#  'map of the russian border showing the location of the border',
#  'a map of the russian border with the names of the countries',
#  'a close up of a man with long hair and sunglasses',
#  "a blue background with a white text that reads, ' russian hoboc '",
#  'a close up of a document with a picture of a person on it',
#  'arafed man with a mustache and a moustache sitting in a chair',
#  'people walking around a park with a statue of jesus in the background',
#  'there is a man sitting in a jail cell with his legs crossed',
#  'arafed man with a guitar and a microphone on stage',
#  'arafed man with a guitar and a microphone in his hand',
#  'arafed man in a red and black outfit holding a microphone',
#  'a close up of a person holding a microphone on a stage',
#  'arafed man in a suit speaking into a microphone',
#  'arafed image of two men shaking hands in front of a group of men',
#  'there is a statue of a man standing on a pedestal',
#  'there is a man skateboarding on a ramp next to a statue',
#  'arafed construction workers are working on a large building under construction',
#  'a close up of a document with a picture of a person on it',
#  'there is a man that is petting a bear in a cage',
#  'araffe walking in a park with a dog and a tree',
#  'arafed man in a suit and tie standing in front of a tree',
#  'arafed man with a beard and a smile on his face',
#  'arafed image of a woman sitting next to a man in a suit',
#  'there are many different types of christmas decorations on the table',
#  'there are two people riding bikes on a path in a park',
#  'hockey player standing on ice with a stick in front of a crowd',
#  'a close up of a woman in a red coat holding a microphone',
#  'a close up of a box of food on a table',
#  'a close up of a cell phone with a lot of different items',
#  'a close up of a cell phone with a sim card attached',
#  'a screenshot of a cell phone with a russian language text',
#  'a close up of a green box with a sticker on it',
#  'a close up of a document with a picture of a person on it',
#  'a close up of a document with a picture of a plane',
#  'a close up of a document with a picture of a plane',
#  'a close up of a document with a picture of a plane',
#  'there is a man in a suit and tie standing next to a man in a suit',
#  'arafed female athlete in yellow outfit holding a pink and purple pole',
#  'hockey players are playing a game of hockey on the ice',
#  'arafed image of a soccer player in a yellow and blue uniform',
#  'three women are smiling and wearing tennis hats and holding tennis rackets',
#  "arafed image of a man in a priest ' s hat holding a shirt",
#  'arafed image of a man in a suit and tie standing in front of a statue',
#  'arafed man walking on a field with a soccer ball',
#  'a close up of a man with a rosary on his neck',
#  'players in red and black uniforms are celebrating a goal',
#  'there is a man holding a cake with a drawing on it',
#  'there are two soccer players standing next to each other on the field',
#  'hockey players sitting on bench in a hockey rink with a coach',
#  'a woman and a man are performing on a ice rink',
#  'arafed collage of a pope handing a soccer jersey to a man',
#  'arafed hockey players are standing on the ice with their sticks',
#  'hockey player in red and white uniform skating on ice with stick',
#  'a close up of a table with a number of different teams',
#  'arafed image of a trophy with a lot of different logos',
#  'a close up of a person in a yellow jacket with a black and white background',
#  'there are two men playing soccer in a stadium with a crowd watching',
#  'hockey players are celebrating a goal with a scoreboard in the background',
#  'arafed hockey player wearing a helmet and goggles with a camera',
#  'arafed soccer player giving thumbs up with his team mates',
#  'two women are shaking hands on a tennis court with flags',
#  'arafed man in black shirt with wrist on a soccer field',
#  'there are two men playing soccer on a field with a score board',
#  'there is a poster of a woman holding a trophy with other women',
#  'arafed man being stretchered off on a soccer field',
#  'a close up of a man in a black jacket with a blue hoodie',
#  'people running in a marathon in a city street with mountains in the background',
#  'hockey players are playing a game of ice hockey on the ice',
#  'arafed image of a soccer match with a player running after the ball',
#  'a close up of a soccer player in a yellow shirt kicking a soccer ball',
#  'arafed man being stretchered off on a soccer field',
#  'araffes of a soccer trophy with a flag in the background',
#  'a close up of a soccer player with a number of different players',
#  'hockey players are posing for a picture with their arms around each other',
#  'arafed image of a man in a red shirt and a red cap',
#  'hockey player celebrating a goal in front of a crowd',
#  'hockey player in blue uniform celebrating after scoring a goal',
#  'hockey player in white and red uniform with stick in hand',
#  'arafed image of a group of people holding tennis rackets',
#  'there are two soccer players that are playing soccer in a match',
#  'there is a man in a suit and tie standing in front of a poster',
#  'arafed image of a group of soccer players celebrating a goal',
#  'a couple of men playing a game of hockey on a field',
#  'arafed image of a soccer player in a red shirt',
#  'arafed image of a group of men in a group of different teams',
#  'a close up of a poster with a line up of different teams',
#  'hockey player in red uniform on ice with stick and other players',
#  'there are many soccer players playing a game on the field',
#  'araffe man in sunglasses walking down the street with a skateboard',
#  'there are two men playing soccer on a field with a crowd watching',
#  'hockey player in uniform with a hat and a jersey',
#  'players are celebrating a goal in a soccer game with a crowd watching',
#  'a close up of a poster with a number of different teams',
#  'arafed car with a smashed windshield and a man in a black shirt',
#  'arafed image of a man in a blue jacket sitting at a table',
#  'a close up of a trophy with a lot of different logos',
#  'hockey players are playing a game of hockey on the ice',
#  'hockey players are playing a game of hockey with a referee',
#  'a close up of a soccer field with a stadium in the background',
#  'arafed swimmer in the pool with water splashing off his face',
#  'there is a man walking on the field with a baseball bat',
#  'arafed photo of a group of soccer players playing soccer',
#  'there is a truck that is pulling a van down the road',
#  'a close up of a table with a number of teams on it',
#  'arafed male in a blue jacket standing in a room',
#  'there is a man that is sitting down with a quote on it',
#  'woman in black jacket and red hoodie standing in front of a blue wall',
#  'there is a man skateboarding on a ramp next to a statue',
#  'a close up of a man running in a race with other men',
#  'arafed tennis player in red shirt and white shorts holding a tennis racket',
#  'arafed tennis player on a clay court with a stick and ball',
#  'a close up of a man in a suit and tie with a star on it',
#  'a close up of a graphic of a trophy with orange and black circles',
#  'woman in a swimming pool with a red cap and a red swim cap',
#  'arafed man in a suit and tie hugging a soccer player',
#  'hockey player in white jersey and red and blue uniform on ice',
#  'hockey players in blue and white uniforms playing a game of hockey',
#  'hockey players posing for a picture with a plaque in a hallway',
#  'a close up of a hockey player with a trophy in front of him',
#  'a close up of a man squatting on a wrestling mat',
#  'a close up of two hockey players on a field with a score',
#  'arafed image of a man in a white uniform with a black background',
#  'a close up of a person in a swimming cap and goggles',
#  'araffe tennis player in a white outfit hitting a tennis ball',
#  'hockey fans are watching a game in a large arena',
#  'two women are playing tennis on a tennis court and one is waving',
#  'hockey players in action on the ice during a game',
#  'araffe woman lifting a barbell in a competition',
#  'there are many people standing together on the ice in a rink',
#  'arafed image of a man sitting at a table with a blue table cloth',
#  'arafed image of two men shaking hands in front of flags',
#  'arafed tennis player serving the ball on a clay court',
#  'there is a man in a suit and tie holding a microphone',
#  'arafed hockey player in a red and blue uniform skating on the ice',
#  'arafed female gymnast performing a stunt on a beam',
#  'there is a man walking on the field in a stadium',
#  'arafed man in a suit and tie sitting in a chair',
#  'arafed image of a woman holding a tennis racket on a court',
#  'two men sitting in chairs in a room with flags and a table',
#  'arafed tennis player in red shirt and white shorts swinging at a tennis ball',
#  'arafed tennis player holding a trophy in front of a crowd',
#  'arafed image of a man and a woman skating in a competition',
#  'a close up of a hockey player with a signed card',
#  'two people in figure skating costumes are performing a trick',
#  'a close up of a trophy with a lot of different logos',
#  'arafed image of a man and a woman skating in a competition',
#  'a group of four pictures of soccer players with different numbers',
#  'there is a man walking on a soccer field with a soccer ball',
#  'a close up of a hockey jersey with the number 95 on it',
#  'a close up of a poster with a hockey trophy on it',
#  'a close up of a soccer game with a ball on the field',
#  'a close up of a soccer player with a number of different teams',
#  'arafed image of a man with a soccer ball in his hand',
#  'arafed hockey players are standing in a line with their helmets on',
#  'arafed image of a soccer match with a player kicking the ball',
#  'hockey players are huddled around each other in a huddle',
#  'hockey players in action on the ice during a game',
#  'arafed man in a blue shirt with his arms crossed',
#  'arafed image of a soccer match with a player in blue and yellow',
#  'female swimmer in orange and yellow swimsuit and sunglasses standing in the water',
#  'arafed male swimmer in a pool with his arm raised',
#  'a close up of a soccer player kicking a ball on a field',
#  'arafed image of a man and a woman skating in a competition',
#  'arafed image of a band performing on stage with a guitar',
#  'arafed man in a pink hat and sunglasses adjusts his sunglasses',
#  'there is a man in a suit holding a cell phone',
#  'blond woman with curly hair wearing a black coat and a black top',
#  'there are two women holding tennis rackets and smiling for the camera',
#  'arafed man in a suit sitting in a chair holding a microphone',
#  'a close up of a document with a picture of a woman',
#  'hockey players in red and grey uniforms are waiting for the next play',
#  'hockey player in a white jersey and green and white uniform',
#  'there is a man in a blue jersey and helmet on a hockey rink',
#  'hockey goalie in red and blue uniform standing on ice',
#  'two girls sitting on a bench holding a heart shaped object',
#  'arafed soccer player with a blue jacket and red stripes',
#  'arafed image of a group of hockey players running with the puck',
#  'there is a man that is kicking a soccer ball on the field',
#  'a close up of a soccer player kicking a soccer ball',
#  'hockey players are playing a game of hockey on the ice',
#  'there are two soccer players that are celebrating a goal',
#  'several pictures of a group of people standing around a soccer field',
#  'hockey players in red uniforms are playing a game of ice hockey',
#  'there is a young man standing in front of a green light',
#  'there are two men playing soccer on a field with a crowd watching',
#  'hockey fans are watching a game in a large arena',
#  'there is a man holding a blue object in his hand',
#  'a close up of two hockey players standing next to each other',
#  'araffe figure performing a stunt with a man on his back',
#  'two men holding up flags in a space station with cameras',
#  'a close up of a hockey player wearing a helmet and a jersey',
#  'arafed image of a group of men in black shirts',
#  'arafed man in a black hat and black jacket making a face',
#  'araffe figure skating in a competition in a black dress',
#  'a close up of a soccer ball with a number of teams on it',
#  'arafed man holding a bouquet of flowers standing next to a woman',
#  'a man in a hockey uniform standing in front of a crowd',
#  'two black and white logos of two different types of birds',
#  'arafed female tennis player in a purple dress holding a tennis racket',
#  'skier in yellow and blue outfit on skis going down a slope',
#  'three women and a man holding flowers and medals standing next to each other',
#  'araffe holding a badminton racket with shuttles in it',
#  'arafed man in a suit and tie standing in a room',
#  'arafed man in a suit and tie looking down',
#  'araffe figure in a red dress skating on a rink',
#  'hockey players posing with trophy and trophy cup in front of a crowd',
#  'hockey players standing next to each other on a ice rink',
#  'arafed man in a suit and tie speaking into a microphone',
#  'arafed image of a woman in a blue uniform dribbling a basketball ball',
#  'arafed hockey player holding a puck in a locker',
#  'a close up of a cell phone with a broken screen',
#  'there is a bag of meat on a cart on a track',
#  'they are standing next to a table with a large piece of meat on it',
#  'there are many people standing on a field with a dog',
#  'a close up of a trophy with a lot of different logos',
#  'arafed image of a woman in a white dress performing a trick',
#  'hockey players are celebrating a goal in a game with a crowd watching',
#  'a close up of a person holding a money bill',
#  'hockey players are playing a game of ice hockey on the ice',
#  'araffe figure in a white dress performing a trick on a skateboard',
#  'hockey player in white and blue uniform with a stick',
#  'there is a man sitting in a locker with a helmet on',
#  'hockey player in white jersey and blue pants skating on ice',
#  'hockey player on ice with a hockey stick in front of a crowd',
#  'arafed hockey player with a red jersey and a man in a suit',
#  'there is a man in a suit and tie sitting at a table',
#  'arafed man in a gray jacket standing in front of a train door',
#  'a close up of a tattoo of a hockey player with a bat',
#  'arafed image of a man in a suit and tie speaking into a microphone',
#  'there is a police van parked in front of a building',
#  'arafed man in a suit and tie standing at a podium with flags behind him',
#  'arafed man in suit and tie standing in front of a screen',
#  'there is a man holding a tennis racket and a tennis ball',
#  'there is a man that is playing tennis on a court',
#  'arafed hockey player with a red jersey and a man in a suit',
#  'arafed man in black shorts posing for a picture',
#  'a table with a number of teams and numbers of teams',
#  'a close up of a bracket with a number of teams on it',
#  'arafed image of a group of hockey players standing in a circle',
#  'arafed image of a man with a beard and a beard in a wrestling uniform',
#  'arafed image of a woman in a black and blue top',
#  'arafed image of a woman with her arms raised in victory',
#  'a close up of a man with a beard and a shirt',
#  'a close up of a man in a wrestling outfit with a medal',
#  'a close up of a table with a number of teams on it',
#  'arafed image of a man in a sweater with a quote on it',
#  'arafed image of a soccer player jumping to head a ball',
#  'there are two people that are holding hands together on a court',
#  'arafed woman in a red and green uniform serving a volleyball ball',
#  'arafix volleyball player jumping up to hit the ball',
#  'arafix woman in red shorts playing volleyball in front of a crowd',
#  'two women in red and green uniforms are standing on a court',
#  'arafed female volleyball player celebrating a point during a game',
#  'players in blue uniforms huddle together in a huddle',
#  'hockey players are playing a game of ice hockey on the ice',
#  'there are two soccer players that are playing soccer on the field',
#  'there are two men playing soccer in a stadium with a crowd watching',
#  'hockey players are playing a game of hockey in front of a crowd',
#  'a close up of a soccer player kicking a soccer ball',
#  'araffe wrestler in blue wrestling suit with arms in the air',
#  'arafed man in a suit and tie giving a thumbs up',
#  'arafed image of a group of men riding skis down a snow covered slope',
#  'arafed man with glasses and a black jacket looking off to the side',
#  'arafed man with a black haircut and a red and white shirt',
#  'there is a man wearing glasses and a suit and tie',
#  'there are many people hiking up a sand dune in the desert',
#  'a man with a tattoo on his chest and a belt',
#  'hockey player in blue jersey and red pants with a hockey stick',
#  'arafed man in a black jacket sitting at a table with a microphone',
#  'there is a man with ear buds on his head and a soccer jersey',
#  'there is a woman that is swimming in the water with her legs up',
#  'a man in a racing uniform standing with his arms crossed',
#  'world record - swimming - screenshote - screenshote - screenshote - world record',
#  'arafed male wrestler in blue wrestling suit with gold trim',
#  'hockey player standing on ice with a sign in front of him',
#  'arafed image of a trophy with a lot of different logos',
#  'a close up of two soccer players running on a field',
#  'hockey players are on the ice with their numbers displayed',
#  'arafed soccer player in yellow uniform running with ball in air',
#  'there are two men that are hugging each other on the field',
#  'there are two men playing soccer on a field with a crowd watching',
#  'hockey players in black jerseys are congratulating each other',
#  'a close up of a table with a number of different teams',
#  'arafed image of a soccer player running after a soccer ball',
#  'arafed man sitting on a wall in a stadium with a red stadium',
#  'arafed man in blue shirt holding a trophy in front of a wall',
#  'there are two men sitting on chairs and one is waving',
#  'several pictures of a soccer player being taken off the field',
#  'there are two soccer players on the field playing soccer',
#  'hockey players are standing together on the ice with their sticks',
#  'araffes figure skating in a competition with a man and a woman',
#  'arafed bridge with olympic rings in the foreground and a barge in the foreground',
#  'hockey players in green and blue uniforms playing a game',
#  'hockey player in a white jersey and blue and orange uniform',
#  'a close up of a hockey player with a signed card',
#  'skiers on a slope with a ski lift in the background',
#  'they are two men standing in a field with carrots on a plate',
#  'a man in a black shirt and black jacket standing in front of a blue screen',
#  'there is a man and a boy that are holding a sign',
#  'several pictures of a man standing in front of a soccer goal',
#  'a close up of a poster with a number of different teams',
#  'a woman in a white dress holding a red and white present',
#  'a close up of a hockey player on a blue background',
#  'arafed image of a man in a suit and tie sitting in a chair',
#  'several people are getting ready to board a bus at the airport',
#  'several people holding signs in a lobby with a crowd of people',
#  'several police officers are walking around with luggage in hand',
#  'arafed man sitting in a chair with a red blanket on a field',
#  'someone is sewing a piece of blue suit with a black and white pattern',
#  'there is a close up of a quilt with a red flower on it',
#  'there is a red shirt with a black top hat on a blue suit',
#  'there is a suit hanging on a hanger in a store',
#  'there is a man sitting on a chair with a jacket on',
#  'there is a man sitting on a chair with a clock on it',
#  'arafed picture of a woman holding a cell phone in her hand',
#  'a close up of a man with a hat and a bag',
#  'arafed man in a blue jacket and plaid pants standing in front of a blue backdrop',
#  'arafed man sitting on a couch with a blue jacket and a blue tie',
#  'arafed image of a hockey player with a helmet on',
#  'arafed image of a soccer player kicking a soccer ball',
#  'arafed image of a soccer match with a player about to kick the ball',
#  'there is a man holding a soccer ball in his hands',
#  'arafed man in a white and blue shirt standing in front of a stadium',
#  'arafed man in a yellow and blue shirt standing with his arms crossed',
#  'there is a man that is smiling and holding a soccer ball',
#  'there is a man sitting in a stadium with yellow chairs',
#  'arafed man in yellow and black jacket standing in front of a fence',
#  'there is a young man holding a soccer jersey in his hands',
#  'arafia is a man with long hair and a blue shirt',
#  'there is a man sitting on a bench in a stadium',
#  'there is a large soccer field with a giant banner on it',
#  'a close up of a row of spools of thread in a factory',
#  'a poster with a red background and a red and yellow background',
#  'there is a man holding a tennis racket in his hand',
#  'there is a man in a suit and tie with a quote on it',
#  'arafed man in a suit and tie standing at a podium',
#  'there is a man in a jacket and sunglasses playing a video game',
#  'there is a man in a snow suit standing in the snow',
#  'there is a statue of a man covered in snow outside',
#  'there is a snowboarder riding down a snowy hill in the snow',
#  'there is a bike parked on a rail in the snow',
#  'arafed seats in a row covered in snow at a baseball game',
#  'snowy stadium seats with a sign in the background',
#  'snowy day at a stadium with a yellow flag in the snow',
#  'there is a man shoveling snow from a pile of tires',
#  'arafed man in red and green jersey holding up his arms',
#  'arafed image of a man holding a trophy in front of a stage',
#  'there is a man and woman standing together in a room',
#  'there is a man in a suit and tie sitting in front of a microphone',
#  'arafed man sitting on a bench with a towel in his hand',
#  'soccer players in action on a soccer field during a game',
#  'arafed tennis player serving the ball on a clay court',
#  'arafed image of a man waving his hand in front of a poster',
#  'skier in red and blue outfit skiing down a hill with other skiers',
#  'there is a man that is standing in front of a crowd',
#  'arafed man in a suit and turtleneck sweater standing in front of a group of men',
#  'a screenshot of a man with a boxing glove and a tweet',
#  'a close up of a bald man in a suit and tie',
#  'arafed man holding a bouquet of flowers standing next to a woman',
#  'a close up of a row of spools of thread in a factory',
#  'a close up of a person on a field with a soccer ball',
#  'a close up of a soccer player with his mouth open',
#  'a poster of two men standing next to each other with one holding a boxing glove',
#  'liverpool players celebrating a goal during a soccer match',
#  'arafed image of a man holding a tennis ball and a tennis racquet',
#  'a poster of a group of men playing basketball on a court',
#  'a close up of a number of soccer teams with a blue background',
#  'arafed figure in a red dress performing a trick on a skateboard',
#  'skier in red and white outfit on skis in the snow',
#  'arafed image of a man in a blue jacket and a blue hat kicking a soccer ball',
#  'arafed photo of a crowd of children and adults at a sporting event',
#  'arafed image of a group of young children holding signs',
#  'arafed hockey player raising his arms in celebration after a goal',
#  'arafed hockey player in green jersey and helmet on ice',
#  'there is a man that is playing tennis on the court',
#  'a close up of a hockey player wearing a helmet and a jersey',
#  'hockey player in uniform with a stick and helmet on',
#  'skier posing for a picture on a snowy trail with trees in the background',
#  'they are standing on a deck overlooking the ocean at sunset',
#  'arafed man holding up a gold and silver belt with a number of medals around his neck',
#  'arafed soccer player standing in front of a goalie net',
#  'arafed man with long hair and a black jacket on',
#  'a close up of a hockey jersey with a number on it',
#  'arafed man in a green and white outfit holding a cell phone',
#  'arafed hockey player in a white and green uniform on the ice',
#  'arafed soccer player in blue shirt holding his head in his hands',
#  'arafed hockey player sitting on a red couch with his hands crossed',
#  'a close up of a soccer player jumping up to head a ball',
#  'a close up of a soccer player with a tattoo on his arm',
#  'arafed hockey player with a stick in his hand on the ice',
#  'a close up of a hockey player on a blue background',
#  'a close up of a large crowd of people in a stadium',
#  'there is a picture of a hockey puck on the ice',
#  'a close up of a roll of fabric with a picture of a cat',
#  'arafed image of a man in a wrestling match and a man in a wrestling suit',
#  'hockey players posing with the trophy and the trophy on the ice',
#  'a close up of a hockey player holding a stick',
#  'arafed man in a white shirt and black shorts holding a tennis racket',
#  'arafed male tennis player celebrating after winning a match',
#  'arafed photo of a man sitting on a basketball court with a basketball',
#  'a close up of a trophy with a number of different logos',
#  'hockey players are on the ice with a scoreboard in front of them',
#  'arafed image of a man in a white and green outfit and a black and white photo of',
#  'arafed image of a man in a purple shirt and a bald man in a black jacket',
#  'there is a notebook with a keyboard and a mouse on a table',
#  'arafed image of a man with a guitar and a guitar',
#  'arafed image of a man shaking hands with a man in a suit',
#  'a close up of a game console with a bunch of stickers on it',
#  'there are two pictures of a man in a blue shirt and a man in a red shirt',
#  'there is a octopus sitting on a couch with a soccer ball and a cell phone',
#  'arafed image of a man holding a soccer ball with a group of men in suits',
#  'arafed image of two men with beards and a man with a beard',
#  'arafed image of two men embracing on a field',
#  'a close up of a poster with a bunch of people on it',
#  'arafed image of a man in a red and blue shirt with a blue and yellow crest',
#  'arafed image of a soccer player in the air with a ball',
#  'arafed image of a soccer player with a number 10 on his chest',
#  'there is a man and woman that are posing for a picture',
#  'several pictures of a soccer team posing for a picture in front of a crowd',
#  'there are two men playing soccer on a field with a crowd watching',
#  'arafed image of a man in a suit pointing at a soccer ball',
#  'arafed man holding a red flag in front of a camera',
#  'arafed man with a red tie and glasses and a man with a red tie',
#  'arafed picture of a man holding a trophy and a shirt',
#  'arafed soccer player standing next to a golden ball',
#  'there are many soccer players in blue uniforms standing together',
#  'there are two men standing next to each other in a room',
#  'arafed man kneeling on the ground with a soccer ball in his hand',
#  'there are two soccer players standing next to each other',
#  'arafed image of a man holding a soccer trophy in front of a stadium',
#  'there are two men playing soccer on a field with a crowd watching',
#  'several pictures of a soccer player being stretchered off the field',
#  'arafed image of a man in a suit standing in front of a flag',
#  'araffes of soccer players are talking on the field',
#  'arafed woman in a purple dress holding a tennis racket',
#  'arafed soccer player sitting on the ground with his foot in the air',
#  'there are a lot of men that are posing for a picture',
#  'arafed image of a man sitting on a bench next to a man in a black jacket',
#  'there is a poster of a hockey player with a hockey stick',
#  'arafed image of two men in a city one is looking at his cell phone',
#  'arafed image of a soccer player jumping to kick the ball',
#  'several pictures of a man with a soccer ball in his hand',
#  'there are two pictures of a man playing soccer in a stadium',
#  'there is a man with his mouth open and a soccer ball in the air',
#  'a close up of a woman in a pink outfit and a group of people',
#  'there are two men that are playing soccer on the field',
#  'there are three different pictures of a young man with a medal',
#  'arafed image of a soccer player celebrating a goal with a crowd watching',
#  'there is a soccer player running with a ball in his hand',
#  'there are two men standing on a soccer field with a referee',
#  'there are two pictures of a man playing soccer on the field',
#  'arafed image of a soccer player with a number on his shirt',
#  'there is a poster of a soccer player holding a trophy',
#  'they are two men talking in a room with people standing around',
#  'three men standing in front of a soccer field with a referee',
#  'arafed image of a man holding a trophy and a man in a red shirt',
#  'there is a man with a shirt on celebrating a goal',
#  'there are two men that are holding basketballs and a ball',
#  'arafed image of a man in a blue hat smiling',
#  'arafed image of a man holding a cell phone and a picture of a man in a lakers',
#  'there is a man holding a shirt with a picture of a lion on it',
#  'there are many pictures of a man with a soccer jersey',
#  'arafed image of a man with a beard and a man with a beard and a man with',
#  'there is a man with sunglasses and a bull head on a shield',
#  'a close up of a poster with a number of different teams',
#  'there are two men hugging each other in a hug',
#  'arafed boy in a red shirt standing on a flight of stairs',
#  'arafed image of a man with a beard and a man with a tie',
#  'there is a man covering his face with his hands',
#  'there are two pictures of a man that are on a track',
#  'arafed image of a man in a suit and tie with a man in a suit and tie',
#  'arafed image of a man with a beard and a black shirt',
#  'a close up of a notepad with a lot of stickers on it',
#  'arafed soccer fans are in the stands watching a game',
#  'two men with different smiles and different teeth are smiling',
#  'arafed image of a man in a black jacket and a man in a white shirt',
#  'arafed man holding a trophy in his hand on a stage',
#  'there are four different pictures of a man with a beard',
#  'arafed image of a man with a beard and a black jacket',
#  'arafed image of a man with a beard and a soccer player',
#  'smiling man in a black burkah holding a helmet and a woman in a black burkah',
#  'arafed image of a man in a suit and a man in a pink jacket',
#  'arafed image of a man in a suit and tie holding a trophy',
#  'two men standing next to a sign in a field with a green field',
#  'there is a picture of a black iphone with a camera on it',
#  'arafed woman in a black swimsuit standing on a step in a pool',
#  'a screenshot of a football match with a score of 10, 000',
#  'there is a man that is hugging another man in a room',
#  'there are two pictures of a man celebrating a goal in a soccer game',
#  'a close up of a table with a number of different teams on it',
#  'arafed image of a young boy in a crowd of people',
#  'there is a man holding a soccer ball in his hands',
#  'arafed image of a group of soccer players celebrating a goal',
#  'there are two soccer players on the field playing soccer',
#  'there are two pictures of a soccer game being played on the field',
#  'there are two soccer players that are celebrating a goal',
#  'there is a man that is holding a soccer ball in his hand',
#  'there is a woman sitting next to a man in a chair',
#  'arafed crowd of people in a stadium with a large banner',
#  'arafed image of a man with a soccer ball and a man with a soccer ball',
#  'there is a soccer player that is standing on the field',
#  'arafed image of a man with a soccer ball and a picture of a soccer team',
#  'a close up of a poster with two men in red racing suits',
#  'a close up of a person playing a video game on a tv',
#  'arafed image of a man with a beard and a black jacket',
#  'there are two pictures of a man with a long hair and a man with a beard',
#  'arafed man in a suit holding a jersey in front of a crowd',
#  'arafed image of a man in a suit and a soccer player in a red scarf',
#  'several pictures of a man being taken off the field by a referee',
#  'arafed image of a group of women soccer players celebrating a goal',
#  'there are two pictures of a man holding a trophy and a video game',
#  'there is a man standing in front of a group of soccer players',
#  'hockey players are wearing jerseys and posing for a picture',
#  'there are two pictures of a soccer player and a soccer player',
#  'there are two pictures of a man in a suit and tie',
#  'arafed image of two men in suits and ties one is wearing a suit',
#  'arafed image of a man in a white shirt and a man in a white shirt',
#  'araffes a man holding a soccer ball in his hands',
#  'two pictures of a man running and a soccer player running',
#  'a close up of a soccer trophy with a number of teams',
#  'a close up of two soccer players on a field with a crowd watching',
#  'there is a man with a soccer jersey on shouting',
#  'several soccer players are playing soccer on a soccer field',
#  'there are many people playing soccer on a field with a crowd watching',
#  'there is a man standing on a soccer field with his arms up',
#  'there are two pictures of a soccer player hugging each other',
#  'there are many people standing around a soccer player shaking hands',
#  'arafed soccer player in pink jersey standing in front of a net',
#  'arafed image of two men with their feet in the air',
#  'several soccer players are playing a game of soccer on a field',
#  'there is a man that is playing soccer on the field',
#  'there are two pictures of a soccer player in action on the field',
#  'arafed soccer game with players on the field and referee watching',
#  'araffes soccer player in a white jersey smiling and looking at the camera',
#  'arafed image of a soccer stadium with a giant banner',
#  'they are holding a framed picture of a jersey with a number on it',
#  'there is a man sitting at a table with a plate of food',
#  'there are two soccer players playing soccer on the field',
#  'there is a man making a heart with his hands on a soccer field',
#  'there are two men hugging each other on the field',
#  'arafed man holding a green cup in front of a green screen',
#  'there is a picture of a man in a police uniform with a dog',
#  'there are two pictures of a soccer match being played on the field',
#  'arafed image of a man holding a pair of shoes in his hands',
#  'arafed figure skating in a competition and a man in a black suit',
#  'arafed image of a man sitting on a red chair in front of a street sign',
#  'arafed man in blue jacket holding a cup and a cup of coffee',
#  'there are many people standing together in front of a soccer ball',
#  'arafed soccer player with his foot on the ground and a soccer player with his head in the',
#  'there is a man holding a cell phone up to his ear',
#  'arafed woman in a black shirt and a woman in a red shirt and a woman in a',
#  'arafed man holding up a score board with a number 30 on it',
#  'arafed man in a suit and tie looking off to the side',
#  'there is a man that is standing in the goalie with a soccer ball',
#  'two men holding trophies in front of a blue background',
#  'arafed man in a black jacket and a man in a black jacket',
#  'arafed soccer player in the air with his team in the background',
#  'a close up of a soccer field with a crowd of people',
#  'there is a soccer game with a goalie in the middle of the goal',
#  'there is a man that is running with a soccer ball',
#  'there is a man laying on the ground on the baseball field',
#  'there are many people playing soccer on a field in a stadium',
#  'hockey players standing on the ice with their sticks in front of the net',
#  'there are two pictures of a soccer player kicking a ball',
#  'arafed man in black jacket pointing at something on a yellow wall',
#  'there are two men playing soccer on a field with a crowd watching',
#  'there are many people playing soccer on a field at night',
#  'there are two soccer players celebrating a goal on the field',
#  'araffe referee giving instructions to a group of soccer players',
#  'there is a man that is standing in front of a soccer field',
#  'there is a man standing in front of a sign with a thumbs up',
#  'there are two pictures of a man kicking a soccer ball',
#  'there is a man kicking a soccer ball on the field',
#  'there is a poster with a man holding a soccer ball',
#  'there are two men standing next to each other with a painting behind them',
#  'there are two pictures of a man playing soccer and a man in a red shirt',
#  'there are two pictures of a man and a boy holding a shirt',
#  'there are two pictures of a man in a green jacket and a man in a yellow jacket',
#  'araffes standing in a line on a soccer field with a referee',
#  'there are two pictures of a man giving a thumbs up',
#  'arafed image of a couple posing in front of a couch',
#  'arafed image of two men with arms crossed and one with his hands folded',
#  'newspapers with a soccer ball and a soccer ball on it',
#  'a close up of a black and white logo with a bird',
#  'arafed image of a man and a woman holding a red jersey',
#  'a man standing in front of a body of water with a mountain in the background',
#  'there are two men that are wearing different shirts in a photo',
#  'there are two men playing soccer on a field with a net',
#  'a close up of a phone with a clock on the screen',
#  'there are two pictures of a man celebrating a goal with a soccer ball',
#  'there is a man that is running with a soccer ball',
#  'there is a man with a soccer jersey on celebrating a goal',
#  'two men are speaking at a podium with microphones and microphones',
#  'arafed image of a man in a white shirt and a black and white jersey',
#  'there are two pictures of a man and a boy in the water',
#  'there are two pictures of a man giving a thumbs up',
#  'there are two pictures of a man and a woman playing basketball',
#  'arafed man in a suit and tie next to a picture of a man in a suit',
#  'a close up of a wii game and a playstation game',
#  'there is a notebook with a keyboard and a mouse on a table',
#  'arafed man holding a soccer ball in front of a welcome sign',
#  'arafed image of a man in a green shirt with a red and yellow crest',
#  'a poster with a number of different teams on it',
#  'hockey players in suits and ties are standing in front of a crowd',
#  'two pictures of a man and a woman holding a sign',
#  'arafed man holding a trophy and a man pointing at it',
#  'hockey players are wearing jerseys and posing for a picture',
#  'arafed image of two men hugging each other in front of a crowd',
#  'two men in red jackets standing on a soccer field',
#  'there is a man holding his hands to his eyes while playing volleyball',
#  'there is a man that is holding a twee board with a number of emoticions',
#  'there are two men shaking hands on a soccer field',
#  'there are two pictures of a man and a man with a soccer ball',
#  'a close up of a man in a suit and a soccer player',
#  'there are two men that are standing on a soccer field',
#  'there are a lot of soccer players on the field playing soccer',
#  'arafed image of a man making a heart with his hands',
#  'there are two pictures of a man in blue soccer uniforms',
#  'there are three men standing next to each other with a harp',
#  'several pictures of a soccer player kicking a soccer ball on a field',
#  'several soccer players are playing soccer on a field with a referee',
#  'arafed image of a man with a goat on his shoulder',
#  'arafed image of a soccer player in a blue jersey and a soccer player in a blue jersey',
#  'two men in green jackets and white caps are talking',
#  'players walking out onto the field with smoke coming out of their mouths',
#  'there are two pictures of a man with a mustache and a beard',
#  'arafed image of a man with a number on his shirt',
#  'there are two pictures of a man with a surprised look on his face',
#  'a close up of a poster with a number of people on it',
#  'there is a man standing in front of a building with a sign',
#  'there is a man that is celebrating a goal with a soccer ball',
#  'arafed woman with a tattoo on her stomach and a woman with a backpack',
#  'arafed image of a man in a red and black shirt kicking a soccer ball',
#  'a close up of a poster with a basketball game on it',
#  'hockey players and coaches are posing for a picture in front of a tv',
#  'there is a man with a backpack on his back in the desert',
#  'there are two pictures of a man in a soccer uniform',
#  'players in yellow and blue uniforms are playing soccer on a field',
#  'two men in green jackets and black pants walking in the rain',
#  'arafed image of a man holding a belt in the air',
#  'arafed man and woman standing in front of a helicopter and a man in a suit',
#  'there are two soccer players playing soccer on the field',
#  'a close up of a soccer player with a soccer ball in his hand',
#  'there are two men walking down the street wearing matching jerseys',
#  'there are two pictures of a soccer game being played on the field',
#  'arafed image of two men with their feet in the air',
#  'a close up of a soccer field with a number of teams',
#  'there are two soccer players on the field playing soccer',
#  'there are two soccer players that are playing soccer on the field',
#  'several people are playing soccer on a green field at night',
#  'there are two soccer players that are congratulating each other',
#  'arafed image of a soccer player with a soccer ball in his hand and a soccer field with',
#  'arafed steak and fries with a man holding up a peace sign',
#  'there are two soccer players playing soccer on the field',
#  'there are two soccer players on the field playing soccer',
#  'araff signing a letter of intent to a man in a red shirt',
#  'arafed image of a man in a blue hat and a purple shirt',
#  'arafano hockey players are congratulating each other in a huddle',
#  'there is a man that is standing in the grass with a soccer ball',
#  'there is a man that is clapping in front of a crowd',
#  'there is a man that is holding a glove up in the air',
#  'there is a poster of a man with a soccer team on it',
#  'arafed image of a man with a soccer ball in his hand',
#  'arafed image of a soccer player running with a soccer ball',
#  'arafed image of two men with glasses and a tie',
#  'there is a man with a beard and a beardless face holding a purple object',
#  'arafed image of a man holding a trophy in front of a flag',
#  'there are many soccer players playing a game of soccer',
#  'there are two pictures of a soccer player being taken off the field',
#  'there are two men riding horses in the same picture',
#  'arafed image of a man in a suit and a man in a suit',
#  'there is a soccer player that is about to kick the ball',
#  'a close up of a poster with a person holding a smart watch',
#  'there is a man in a red shirt standing next to a man in a black jacket',
#  'arafed image of a man with a beard and a pink shirt',
#  'there are two pictures of a man in a red shirt playing soccer',
#  'arafed image of a man with a soccer jersey and a man with a soccer jersey',
#  'arafed image of a woman in a black and white outfit and a man in a white and',
#  'actors in suits and ties are fighting with each other',
#  'there is a train that is going down the tracks with a soccer ball',
#  'arafed man with a bald head and a bald man with a beard',
#  'arafed image of a man and woman smiling and a man in a suit and tie',
#  'smiling man in blue shirt sitting at a desk with books and a pencil',
#  'there are two pictures of a man in a green shirt and a man in a green shirt',
#  'hockey player with a puck and jersey with a signed puck',
#  'arafed man sitting on a chair in a stadium with a red blanket',
#  'arafed image of a man with a picture of his face on a banner',
#  'a poster with a number of different teams on it',
#  'there is a man sitting on a chair with a tie on',
#  'arafed image of two men with their feet in the air',
#  'there are two pictures of a soccer match with a player kicking the ball',
#  'there is a soccer player that is running after the ball',
#  'there are two soccer players that are standing next to each other',
#  'there is a soccer player jumping up to kick the ball',
#  'arafed image of a man with a soccer ball and a red bull logo',
#  'soccer players on a field playing soccer with a crowd watching',
#  'arafed soccer player in yellow and blue uniform running with ball',
#  'there is a man pointing at the camera with a soccer ball in his hand',
#  'arafed man hugging a woman in front of a wall with a lot of logos',
#  'arafed man in a red jacket and a fur hat',
#  'there are two pictures of a man in a pink suit and a man in a black suit',
#  'arafed image of a man holding a trophy in front of a map',
#  'arafed image of a man with a soccer ball and a man with a soccer ball',
#  'arafed image of a man holding a trophy and a soccer player',
#  'hockey players in blue uniforms are standing on the ice',
#  'arafed image of a man standing next to a blue sports car',
#  'arafed image of two soccer players with their fingers crossed',
#  'a close up of a man on a soccer field with a soccer ball',
#  'arafed image of a group of soccer players on a field',
#  'there is a man standing in front of a poster with a trophy',
#  'there are three pictures of a man in a yellow shirt and a man in a blue hat',
#  'there are two pictures of a man in a soccer uniform',
#  'arafed image of a group of soccer players posing for a picture',
#  'a close up of a person holding a soccer ball in front of a crowd',
#  'there are two soccer players celebrating a goal with a crowd watching',
#  'there are two pictures of a soccer game being played on the field',
#  'araffe man in a white shirt and a man in a black jacket',
#  'there are two pictures of a soccer match with a player celebrating',
#  'there are two pictures of a man laying on the ground playing soccer',
#  'there are two pictures of a soccer player on the field',
#  'arafed soccer player holding a flag on a field',
#  'there are two pictures of a soccer player with a ball in his hand',
#  'there are two pictures of a man sitting on the ground',
#  'there is a woman in a black dress and a woman in a black dress',
#  'two soccer players are standing next to each other on a field',
#  'arafed man in a black jacket looking at the camera',
#  'a close up of a poster with two men playing chess',
#  'there are two men holding trophies and one is drinking',
#  'there are two men that are standing next to each other',
#  'there are two pictures of a man on a television screen',
#  'arafed image of a man in yellow and black soccer uniforms',
#  'there are two pictures of a man holding a trophy and a soccer player',
#  'arafed image of a man holding a pair of shoes in his hands',
#  'two women are posing for a picture while holding skis',
#  'arafed image of a man kneeling down next to a man in a suit',
#  'there are two pictures of a man on the field and a man on the ground',
#  'arafed bald man in black jacket and black shirt clapping',
#  'there are two men that are holding up a shirt',
#  'there are a lot of soccer players playing on the field',
#  'there are two soccer players playing soccer in front of a crowd',
#  'there is a man that is standing on a soccer field',
#  'there is a man with a surprised look on his face',
#  'soccer players celebrating a goal in a stadium with a banner',
#  'soccer players on a field playing soccer with a crowd watching',
#  'there is a man that is standing on a soccer field',
#  'arafed hockey player sitting on a red couch with his hands crossed',
#  'arafed image of a woman in a red dress and a man in a black suit',
#  'arafed image of a man in a suit and a man in a hockey uniform',
#  'a close up of two men in uniforms one with a basketball ball',
#  'there is a man in a blue uniform standing in front of a soccer team',
#  'there are two pictures of a hockey player with a red jersey',
#  'arafed image of a group of hockey players celebrating a goal',
#  'a group of men are celebrating a soccer game with a trophy',
#  'arafed man laying on the ground with a soccer ball in his hand',
#  'there are three people and two children posing for a picture',
#  'arafed billboard with a picture of a man on it',
#  'there are two men standing next to each other with a purple speaker',
#  'arafed man in white shirt standing on cliff with mountains in background',
#  'two men are wearing different soccer uniforms and one is shouting',
#  'there are two pictures of a man playing soccer and a soccer player',
#  'three men standing next to each other in front of a green screen',
#  'there are two pictures of a man with a hockey helmet on',
#  'there are two men that are holding a soccer trophy',
#  'arafed soccer player with a black coat and a blue uniform',
#  'a close up of a red poster with a white and blue sign',
#  'there are two pictures of a man kneeling on a soccer field',
#  'arafed image of a man in a black shirt and a man in a red shirt',
#  'arafed image of a man holding a bottle of alcohol and a picture of a man holding a',
#  'there are many soccer players huddled together in a huddle',
#  'there is a soccer player kicking a soccer ball on the field',
#  'there are many different languages on the screen of this phone',
#  'arafed view of a large stadium with a crowd of people',
#  'there are two pictures of a man in a blue shirt and a man in a orange vest',
#  'there are two men posing for a picture with a trophy',
#  'there are two pictures of a man with thumbs up and a man with a thumbs up',
#  'a close up of a poster with a number of different teams',
#  'arafed man hugging a man in a black shirt on a soccer field',
#  'a woman in a black dress holding a card with a cat on it',
#  'there are two people standing in front of a table with a cake and sparklers',
#  'there are two pictures of a man playing soccer with a ball',
#  'there are many men standing in a locker with soccer uniforms',
#  'there are two pictures of a man playing cards at a bar',
#  'there is a man that is throwing a ball in the air',
#  'there are two pictures of a man with a hockey trophy',
#  'arafed soccer player celebrating with arms outstretched in celebration',
#  'they are two men posing for a picture with a box',
#  'arafed image of a hockey player with a stick and a number of numbers',
#  'a close up of a hockey player holding a stick',
#  'there is a man with a red shirt and a tie looking at the camera',
#  'arafed image of a man in a hockey uniform with a helmet on',
#  'there are four different stickers of a man with a beard',
#  'a close up of two soccer players with a number of different numbers',
#  'a close up of a person holding a cell phone in front of a screen',
#  'a close up of two soccer players standing next to each other',
#  'arafed soccer player in action on the field with a soccer ball',
#  'there is a man holding a cell phone in his hand',
#  'a map of the world cup teams with their numbers',
#  'a close up of a pie chart with a lot of money in it',
#  'a close up of two men in soccer uniforms with a purple background',
#  'a screenshot of a cell phone showing a number of countries',
#  'players celebrating a goal in front of a crowd of fans',
#  'a close up of a soccer player with a soccer ball',
#  'a close up of a cell phone with a casino chip on it',
#  'arafed image of a man in a suit and tie with a logo on it',
#  'arafed tiger wearing glasses and a baseball cap with a red shirt',
#  'there is a man standing on a balcony holding a soccer ball',
#  'there are four men in white shirts and hats standing together',
#  'a close up of a trophy with a bunch of different teams around it',
#  'arafed image of a football match with a scoreboard showing the teams',
#  'arafed soccer player laying on the ground with a ball in his hand',
#  'a close up of a referee wearing a yellow shirt and black pants',
#  'arafed image of a football scoreboard with the names of the teams',
#  'a close up of a soccer score sheet with a team on it',
#  'a screenshot of a soccer player with a number of players',
#  'a close up of a cell phone with a casino chip on it',
#  'a close up of a soccer team posing for a picture',
#  "a heat map of barcelona ' s pitch with the name of the club",
#  'arafed soccer player on the ground with a head on his knees',
#  'arafed image of a football scoreboard with the teams names',
#  'a screenshot of a man in a suit and tie with a microphone',
#  'a close up of a soccer card with a number of teams',
#  'a close up of a soccer score board with a number of teams',
#  'a poster of a group of soccer players standing next to each other',
#  'arafed image of a man with a soccer ball in his mouth',
#  'four different pictures of a man with a soccer uniform and a soccer ball',
#  'the official team crests for the 2013 - 2020 season',
#  'a screenshot of a twitter account with a number of different messages',
#  'a close up of a twee with a picture of a person on it',
#  'arafed image of a trophy with a lot of numbers on it',
#  'a close up of a scoreboard with a number of goals',
#  "a group of men standing next to each other with the words ' овеи 4 '",
#  'there is a picture of a tennis ball and a tennis racket',
#  'a close up of a table with a number of teams on it',
#  'a close up of a number of different logos on a white background',
#  'a close up of a person wearing sunglasses and a hat',
#  'there is a picture of a tennis ball and a tennis racket',
#  'a close up of a soccer score board with a number of teams',
#  'four different pictures of a man talking on a cell phone',
#  'arafed image of a man in a suit and tie watching a soccer game',
#  'there is a little boy and a little girl standing next to a bag of rice',
#  'arafed screenshot of a soccer match with a scoreboard showing the teams',
#  'a close up of a poster with a number of teams on it',
#  'a close up of a poster with a number of soccer players',
#  'a close up of a soccer card with a number of teams',
#  'arafed image of a table with a number of different teams',
#  'a close up of a hockey player holding a stick',
#  'a close up of a poster with a number of different teams',
#  'there is a picture of a tennis ball and a tennis racket',
#  'arafed hockey player with a stick in his hand',
#  "a close up of a person ' s tweeing on a black background",
#  'a close up of a soccer score board with a number of shots',
#  'a poster of a man with his mouth open and a man with his hands crossed',
#  'a close up of a soccer score board with a number of teams',
#  'arafed image of a football scoreboard with the names of the teams',
#  'there is a cartoon picture of a man and a soccer player',
#  'a screenshot of a table with a number of different teams',
#  'two men are facing each other in a video game',
#  'a close up of a soccer score board with a number of teams',
#  'arafed picture of a collage of a man holding a trophy',
#  'a group of men holding trophies and posing for a picture',
#  'a close up of a person with a soccer ball and a picture of a man',
#  'a close up of a cell phone with a number of different countries on it',
#  'a close up of a soccer player celebrating a goal with his team mates',
#  'arafed cat sitting on a table next to a man with a ball',
#  'a close up of a person in a blue uniform on a field',
#  'there is a picture of a tennis ball and a tennis racket',
#  'an aerial view of a stadium lit up at night',
#  'arafed view of a stadium with a large red roof',
#  'two pictures of a man with a smile and a man with a beard',
#  'arafed image of a poster with a number of players',
#  'a close up of a poster with a number of soccer players',
#  'a close up of a person holding a trophy in front of a crowd',
#  'a close up of a poster with a number of soccer players',
#  'a close up of two men on a soccer field with a scoreboard',
#  'a close up of a soccer player with a number of different faces',
#  'arafed image of a man in a red shirt holding a soccer ball',
#  'a close up of a soccer player with a picture of him',
#  'a close up of a soccer player with a number of numbers',
#  'a close up of a black and gold poster with a price list',
#  'arafed image of a man with a trophy in front of a blue background',
#  'arafed image of a man celebrating a goal with his team mates',
#  'two men are smiling and one is wearing a yellow shirt',
#  'there is a picture of a tennis ball and a tennis racket',
#  'a couple of pictures of a group of men standing next to each other',
#  'there is a picture of a tennis ball and a tennis racket',
#  'a close up of a person on a field with a soccer ball',
#  'arafed collage of a man in a red shirt kicking a soccer ball',
#  'a close up of a person with a medal and a person with a medal',
#  'a close up of four different pictures of people with beards',
#  'four different faces of people with different expressions on them',
#  'a close up of a person with a beard and a man with a beard',
#  'four different pictures of a man with a beard and glasses',
#  'a close up of four different pictures of a man with a hoodie',
#  'a group of four pictures of the same actors',
#  'a close up of a person with a bunch of different facial expressions',
#  'a picture of a man with a beard and a crown on his head',
#  'there are four pictures of a man with different facial expressions',
#  'a close up of a number of flags on a white background',
#  'a white background with a number of different flags and a number of words',
#  'a close up of a white sheet with a flag and a red and green flag',
#  'a close up of a cell phone with a number of different logos',
#  'a close up of a purple card with a number of different flags',
#  'a close up of a cell phone with a casino chip on it',
#  'there are two pictures of a man holding a trophy and a man holding a trophy',
#  ...]

# %%
# ------------------------
# 4. Построение BLIP индекса (blip_index)
# ------------------------
blip_captions = []
blip_valid_paths = []  # Аналогично, список корректных изображений

print("Генерация подписей для изображений (BLIP)...")
for img_path in news_image_paths:
    try:
        image = Image.open(img_path).convert("RGB")
    except Exception as e:
        print(f"Ошибка при загрузке изображения {img_path}: {e}")
        continue
    inputs = blip_processor(images=image, return_tensors="pt")
    with torch.no_grad():
        generated_ids = blip_model.generate(**inputs)
    caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
    blip_captions.append(caption)
    blip_valid_paths.append(img_path)

print(f"Сгенерировано подписей для {len(blip_captions)} изображений.")

# Опционал ьно: создание FAISS индекса для эмбеддингов подписей с использованием модели SentenceTransformer
blip_caption_embeddings = model.encode(blip_captions, show_progress_bar=True)
blip_caption_embeddings = np.array(blip_caption_embeddings).astype("float32")
d_blip = blip_caption_embeddings.shape[1]
blip_index = faiss.IndexFlatL2(d_blip)
blip_index.add(blip_caption_embeddings)
print(f"Число подписей в BLIP индексе: {blip_index.ntotal}")

# %%
import pickle

# Сохраняем индекс Faiss
faiss.write_index(blip_index, "/content/drive/MyDrive/Diploma/blip_index_last.faiss")

# Сохраняем пути к изображениям, соответствующие эмбеддингам
with open("/content/drive/MyDrive/Diploma/blip_captions.pkl", "wb") as f:
    pickle.dump(blip_captions, f)

print("CLIP индекс и пути к изображениям успешно сохранены.")

# %% [markdown]
# # Using CLIP+BLIP

# %%
# ------------------------
# 5. Функция поиска по изображениям (с использованием CLIP и BLIP)
# ------------------------

def truncate_query(query: str, max_length: int = 76) -> str:
    """
    Обрезает текстовый запрос до допустимой длины для CLIP-модели (максимум 77 токенов).
    """
    tokens = clip_tokenizer.tokenize(query)
    if len(tokens) > max_length - 2:  # учитываем специальные токены [CLS] и [SEP]
        tokens = tokens[:max_length - 2]
    return clip_tokenizer.convert_tokens_to_string(tokens)


def retrieve_similar_images(query: str, k: int = 5):
    """
    По заданному текстовому запросу с помощью CLIP модели
    ищет наиболее релевантные изображения из clip_index,
    после чего для найденных изображений возвращает соответствующие подписи (BLIP).
    Возвращается список кортежей (путь_к_изображению, подпись).
    """
    # Обрезаем запрос до допустимой длины
    safe_query = truncate_query(query)

    # Получаем текстовое представление запроса
    text_input = clip_processor(text=safe_query, return_tensors="pt")
    with torch.no_grad():
        text_features = clip_model.get_text_features(**text_input)
    text_features = text_features.cpu().numpy().astype("float32")

    # Поиск в CLIP индексе
    distances, indices = clip_index.search(text_features, k)
    retrieved = []
    for idx, dis in zip(indices[0], distances[0]):
        image_path = clip_valid_paths[idx]
        caption = blip_captions[idx]
        retrieved.append((image_path, caption, dis))
    return retrieved


sample_query = "Президент"
similar_images = retrieve_similar_images(sample_query, k=3)
print("Найденные изображения и подписи:")
for img_path, caption, distance in similar_images:
    print(f"Дистанция: {distance} - Изображение: {img_path} - Подпись: {caption}")
# Out:
# Найденные изображения и подписи:
# Дистанция: 436.0837097167969 - Изображение: /Applications/Study/Diploma/images/igmtv_6807.jpg - Подпись: there is a piece of bread and a piece of cheese on a plate
# Дистанция: 439.29296875 - Изображение: /Applications/Study/Diploma/images/rasofficial_12256.jpg - Подпись: there is a man in a blue suit holding a microphone
# Дистанция: 441.98614501953125 - Изображение: /Applications/Study/Diploma/images/rasofficial_12154.jpg - Подпись: there is a picture of a city with a clock tower
